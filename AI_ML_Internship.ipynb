# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Read and Display the Original Image**

# %%
# Load the image
image_path =  r"C:\Users\laxmi\OneDrive\Pictures\Screenshots\Screenshot 2024-07-10 125731.png"
image = cv2.imread(image_path)
cv2.imshow("original image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# **Croping the intresed are from the origina image using Corner points and  perspective transform matrix**

# %%
# Define the four corner points of the rotated square
pts_src = np.array([[48, 159], [191, 50], [298, 183], [164, 293]], dtype=np.float32)


# Define the destination points to get a straightened view
width = max(int(np.linalg.norm(pts_src[0] - pts_src[1])), int(np.linalg.norm(pts_src[2] - pts_src[3])))
height = max(int(np.linalg.norm(pts_src[1] - pts_src[2])), int(np.linalg.norm(pts_src[3] - pts_src[0])))

pts_dst = np.array([[0, 0], [width - 1, 0], [width - 1, height - 1], [0, height - 1]], dtype=np.float32)

# Compute the perspective transform matrix
M = cv2.getPerspectiveTransform(pts_src, pts_dst)

# Apply the perspective transformation
warped_image = cv2.warpPerspective(image, M, (width, height))

# %% [markdown]
# **Display the cropped Image from the original image**

# %%
plt.imshow(cv2.cvtColor(warped_image, cv2.COLOR_BGR2RGB))
plt.title("Cropped Hair Image")
plt.show()

# %%
image_path =  r"C:\Users\laxmi\OneDrive\Desktop\hair_image.jpg"
image = cv2.imread(image_path)
plt.imshow(image)

# %%
# Define the four corner points of the rotated square
pts_src = np.array([[83,45], [57,331],[372, 335],[330,48]], dtype=np.float32)


# Define the destination points to get a straightened view
width = max(int(np.linalg.norm(pts_src[0] - pts_src[1])), int(np.linalg.norm(pts_src[2] - pts_src[3])))
height = max(int(np.linalg.norm(pts_src[1] - pts_src[2])), int(np.linalg.norm(pts_src[3] - pts_src[0])))

pts_dst = np.array([[0, 0], [width - 1, 0], [width - 1, height - 1], [0, height - 1]], dtype=np.float32)

# Compute the perspective transform matrix
M = cv2.getPerspectiveTransform(pts_src, pts_dst)

# Apply the perspective transformation
warped_image = cv2.warpPerspective(image, M, (width, height))

# %%
plt.imshow(cv2.cvtColor(warped_image, cv2.COLOR_BGR2RGB))
plt.title("Cropped Hair Image")
plt.show()
